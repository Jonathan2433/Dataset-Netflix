# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonathan2433/Dataset-Netflix/blob/main/Stream_Formation_Python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
# Affichage de toutes les collones 
pd.set_option('max_columns', None)

# ouverture et lecture du fichier
data = pd.read_csv("https://raw.githubusercontent.com/Jonathan2433/Stream-Foramtion-python/main/netflix_titles.csv")

# copie du fichier pour eviter la mauvaise manipulation sur notre fichier
df = data.copy()

# affichage des 5 premieres lignes de notre dataframe
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# caracteristique de notre dataframe (lignes, column)
df.shape
# Out:
# (8807, 12)

# %%
# affichage des types de chacune de nos collones 

data.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# transformation de notre dataframe en array numpy

df_array = df.values

# affichage de notre array
display(df_array)
# Out:
# array([['s1', 'Movie', 'Dick Johnson Is Dead', ..., '90 min',
#         'Documentaries',
#         'As her father nears the end of his life, filmmaker Kirsten Johnson stages his death in inventive and comical ways to help them both face the inevitable.'],
#        ['s2', 'TV Show', 'Blood & Water', ..., '2 Seasons',
#         'International TV Shows, TV Dramas, TV Mysteries',
#         'After crossing paths at a party, a Cape Town teen sets out to prove whether a private-school swimming star is her sister who was abducted at birth.'],
#        ['s3', 'TV Show', 'Ganglands', ..., '1 Season',
#         'Crime TV Shows, International TV Shows, TV Action & Adventure',
#         'To protect his family from a powerful drug lord, skilled thief Mehdi and his expert team of robbers are pulled into a violent and deadly turf war.'],
#        ...,
#        ['s8805', 'Movie', 'Zombieland', ..., '88 min',
#         'Comedies, Horror Movies',
# ...

# %%
#  accéder à une colonne d’un data frame
df['type']
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3       TV Show
# 4       TV Show
#          ...
# 8802      Movie
# 8803    TV Show
# 8804      Movie
# 8805      Movie
# 8806      Movie
# Name: type, Length: 8807, dtype: object

# %%
# on renomme la colonne list_in par category ET rating par classification

df.rename(columns={'listed_in': 'category', 'rating': 'classification'})
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# changement de type d'une collone 
# df['rating'].astype(float)

# %%
# tri d'un data frame

#trier selon l’identifiant par ordre décroissant :
df.sort_values('release_year', ascending = False)
# Out:
#      show_id     type                                          title  \
# 693     s694    Movie                         Ali & Ratu Ratu Queens
# 781     s782    Movie          Black Holes | The Edge of All We Know
# 762     s763    Movie                                   Sweet & Sour
# 763     s764  TV Show                                    Sweet Tooth
# 764     s765    Movie                   Trippin' with the Kandasamys
# ...      ...      ...                                            ...
# 8660   s8661    Movie  Undercover: How to Operate Behind Enemy Lines
# 8763   s8764    Movie                WWII: Report from the Aleutians
# 8205   s8206    Movie                           The Battle of Midway
# 7790   s7791    Movie                                 Prelude to War
# 4250   s4251  TV Show              Pioneers: First Women Filmmakers*
#
#             director                                               cast  \
# ...

# %%
# trier selon le type puis le title, par ordre croissant :
df.sort_values(['type', 'title'])
# Out:
#      show_id     type                                title  \
# 2036   s2037    Movie                               #Alive
# 2304   s2305    Movie        #AnneFrank - Parallel Stories
# 2481   s2482    Movie                    #FriendButMarried
# 2324   s2325    Movie                  #FriendButMarried 2
# 5973   s5974    Movie                                #Roxy
# ...      ...      ...                                  ...
# 5974   s5975  TV Show                  แผนร้ายนายเจ้าเล่ห์
# 2998   s2999  TV Show  ​SAINT SEIYA: Knights of the Zodiac
# 6177   s6178  TV Show                             忍者ハットリくん
# 4914   s4915  TV Show                                 海的儿子
# 7101   s7102  TV Show                                 마녀사냥
#
#                          director  \
# 2036                       Cho Il
# 2304  Sabina Fedeli, Anna Migotto
# 2481                Rako Prijanto
# 2324                Rako Prijanto
# 5973              Michael Kennedy
# ...                           ...
# ...

# %%
# Comment procéder si on souhaite avoir l’un par ordre croissant et l’autre par ordre décroissant ?

df.sort_values(['type', 'title'], ascending=[True, False])
# Out:
#      show_id     type                 title           director  \
# 7108   s7109    Movie   최강전사 미니특공대 : 영웅의 탄생      Young Jun Lee
# 5022   s5023    Movie               반드시 잡는다      Hong-seon Kim
# 4667   s4668    Movie  ​​Kuch Bheege Alfaaz               Onir
# 5970   s5971    Movie           ​Mayurakshi        Atanu Ghosh
# 5969   s5970    Movie    ​Maj Rati ​​Keteki  Santwana Bardoloi
# ...      ...      ...                   ...                ...
# 5984   s5985  TV Show           100% Hotter                NaN
# 2816   s2817  TV Show            100 Humans                NaN
# 1583   s1584  TV Show    100 Days My Prince                NaN
# 2140   s2141  TV Show              (Un)Well                NaN
# 2666   s2667  TV Show              #blackAF                NaN
#
#                                                    cast         country  \
# 7108  Um Sang-hyun, Yang Jeong-hwa, Jeon Tae-yeol, S...             NaN
# ...

# %%
# sélectionner le director des 10 premiers titres :
df.iloc[:10, 3]
# Out:
# 0                  Kirsten Johnson
# 1                              NaN
# 2                  Julien Leclercq
# 3                              NaN
# 4                              NaN
# 5                    Mike Flanagan
# 6    Robert Cullen, José Luis Ucha
# 7                     Haile Gerima
# 8                  Andy Devonshire
# 9                   Theodore Melfi
# Name: director, dtype: object

# %%
# sélectionner le titre et le director des 10 derniers titres :
df.iloc[-10:, [1, 3]]
# Out:
#          type                 director
# 8797  TV Show                      NaN
# 8798    Movie  Chandra Prakash Dwivedi
# 8799    Movie           Avadhoot Gupte
# 8800  TV Show                      NaN
# 8801    Movie          Majid Al Ansari
# 8802    Movie            David Fincher
# 8803  TV Show                      NaN
# 8804    Movie          Ruben Fleischer
# 8805    Movie             Peter Hewitt
# 8806    Movie              Mozez Singh

# %%
# la sélection via des conditions

df.loc[ df['director'] == "David Fincher", :]
# Out:
#      show_id   type                            title       director  \
# 600     s601  Movie                         The Game  David Fincher
# 1595   s1596  Movie                             MANK  David Fincher
# 7701   s7702  Movie                       Panic Room  David Fincher
# 8320   s8321  Movie  The Girl with the Dragon Tattoo  David Fincher
# 8511   s8512  Movie               The Social Network  David Fincher
# 8802   s8803  Movie                           Zodiac  David Fincher
#
#                                                    cast  \
# 600   Michael Douglas, Sean Penn, Deborah Kara Unger...
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 7701  Jodie Foster, Forest Whitaker, Dwight Yoakam, ...
# 8320  Daniel Craig, Rooney Mara, Christopher Plummer...
# 8511  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
#
#                             country         date_added  release_year rating  \
# ...

# %%
# la sélection via des conditions #2

df.loc[ df['title'] == "Stranger Things", :]
# Out:
#      show_id     type            title director  \
# 3685   s3686  TV Show  Stranger Things      NaN
#
#                                                    cast        country  \
# 3685  Winona Ryder, David Harbour, Finn Wolfhard, Mi...  United States
#
#         date_added  release_year rating   duration  \
# 3685  July 4, 2019          2019  TV-14  3 Seasons
#
#                                          listed_in  \
# 3685  TV Horror, TV Mysteries, TV Sci-Fi & Fantasy
#
#                                             description
# 3685  When a young boy vanishes, a small town uncove...

# %%
# la sélection via des conditions #3

df.loc[ (df['director'] == "David Fincher") & (df['rating'] == "PG-13"), :]
# Out:
#      show_id   type               title       director  \
# 8511   s8512  Movie  The Social Network  David Fincher
#
#                                                    cast        country  \
# 8511  Jesse Eisenberg, Andrew Garfield, Justin Timbe...  United States
#
#          date_added  release_year rating duration listed_in  \
# 8511  April 1, 2020          2010  PG-13  121 min    Dramas
#
#                                             description
# 8511  Director David Fincher's biographical drama ch...

# %%
# affichage de l’ensemble des index de notre data frame.

df.index
# Out:
# RangeIndex(start=0, stop=8807, step=1)

# %% [markdown]
# # “Une image vaut mille mots.”

# %% [markdown]
# Lorsqu’il est question de représentation ou de graphique, de nombreux choix s’offrent à nous. On peut citer de façon non exhaustive :
#
# les courbes pour représenter une évolution d’une caractéristique (comme la démographie d’un pays) dans le temps ;
#
# les graphiques circulaires (appelés plus vulgairement des graphiques camemberts) pour représenter une répartition ;
#
# ou encore des cartes lorsqu’on souhaite afficher une information géographique.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Chaque représentation graphique a une fonction correspondante avec Matplotlib :
#
# nuage de points ou scatter plot, en anglais :scatter() ;
#
# diagrammes en ligne ou en courbes :plot() ;
#
# diagrammes en barres :bar() ;
#
# histogrammes :hist() ;
#
# diagrammes circulaires :pie() .

# %% [markdown]
# ## Le nuage de points

# %%
plt.scatter(df[:100]['show_id'], df[:100]['release_year'])

# %% [markdown]
# Il existe de nombreuses options pour personnaliser un nuage de points. On peut modifier :
#
# la couleur des points, en utilisant l’argumentcolor ouc ;
#
# la taille des points, via l’argumentsize ous ;
#
# le type de marqueur via l’argumentmarker ;
#
# la transparence des points via l’argumentalpha .
#
# https://matplotlib.org/3.5.0/api/_as_gen/matplotlib.pyplot.scatter.html

# %%
plt.scatter(df[-20:]['show_id'], df[-20:]['release_year'],
    s=60, alpha=0.5, c='red', marker='P')

# %% [markdown]
# # Le diagramme circulaire

# %%
# Enregistrement des totaux de films et series

data = df['type'].value_counts()

plt.pie(data, labels=data.index, 
        autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9f21f12a90>,
# ...
#  [Text(-0.897672126570692, -0.6357552620136555, 'Movie'),
#   Text(0.8976721265706921, 0.6357552620136554, 'TV Show')],
#  [Text(-0.4896393417658319, -0.3467755974619939, '69.6%'),
#   Text(0.48963934176583196, 0.3467755974619938, '30.4%')])

# %%
# Enregistrement des totaux de films et series
df['release_year']
data = df.groupby('release_year')['release_year'].count()

plt.pie(data, labels=data.index, 
        autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9f21889610>,
# ...
#  [Text(-0.0003923869395982715, 1.099999930014766, '1925'),
#   Text(-0.0015695472590971106, 1.0999988802364309, '1942'),
#   Text(-0.0035314764899771743, 1.0999943312007572, '1943'),
#   Text(-0.005885776208857093, 1.0999842533593012, '1944'),
#   Text(-0.008632424346646418, 1.0999661273193369, '1945'),
#   Text(-0.010986651967392439, 1.0999451320309335, '1946'),
#   Text(-0.012163747578703268, 1.09993274487345, '1947'),
#   Text(-0.013340829259934111, 1.0999190980588789, '1954'),
#   Text(-0.015302597470143049, 1.0998935541727057, '1955'),
#   Text(-0.017264317000550946, 1.099864511364243, '1956'),
#   Text(-0.019225981610641013, 1.0998319697258794, '1958'),
#   Text(-0.020795269567595868, 1.0998034173267563, '1959'),
#   Text(-0.022756819570443107, 1.099764578063432, '1960'),
#   Text(-0.02471829718052024, 1.0997222402881992, '1961'),
#   Text(-0.026287422977806015, 1.099685851228971, '1962'),
# ...

# %%
plt.bar(height = data, x = data.index)
# Out:
# <BarContainer object of 74 artists>

# %%
data_sorted = data.sort_values(ascending=True)
plt.bar(height=data_sorted, x=data.index)
# Out:
# <BarContainer object of 74 artists>

# %%
plt.hist([data])
# Out:
# (array([60.,  4.,  2.,  1.,  1.,  1.,  0.,  1.,  3.,  1.]),
#  array([1.0000e+00, 1.1560e+02, 2.3020e+02, 3.4480e+02, 4.5940e+02,
#         5.7400e+02, 6.8860e+02, 8.0320e+02, 9.1780e+02, 1.0324e+03,
#         1.1470e+03]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(data.index, data)

# %%
plt.plot(data.index, data,
marker='o', linestyle='--', color='red')

# %%
# data = df.groupby('type')['title'].sum()
# data = data.reset_index()

labels = 'Allemagne', 'France', 'Belgique', 'Espagne'
sizes = [15, 80, 45, 40]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']

# déclaration du graphique
plt.pie(sizes, labels=labels, colors=colors, 
        autopct='%1.1f%%', shadow=True, startangle=90)

# sauvegarde en png du graphique
plt.savefig('PieChart01.png')

# %%
plt.bar(height =  sizes, x = labels)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist([sizes])
# Out:
# (array([1., 0., 0., 1., 1., 0., 0., 0., 0., 1.]),
#  array([15. , 21.5, 28. , 34.5, 41. , 47.5, 54. , 60.5, 67. , 73.5, 80. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## SEABORN

# %%
import seaborn as sns
sns.scatterplot(data=df, x='title', y='release_year')
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 28023 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 30340 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 20799 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 23376 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
